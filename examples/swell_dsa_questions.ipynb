# %% [markdown]
# # Populating a Relational Database
# ## DSA Interview Questions
# In this example we will build and populate a SQLite database with DSA interview questions.

# %% [markdown]
# ## Creating the initial database
# Let's create our initial tables. First, we will populate the smaller question type and question level tables. Then, we will populate the larger *question* table.

# %%
import pandas as pd
import pyarrow as pa
import sqlite3
import os

os.remove("dsa.db")
conn = sqlite3.connect("dsa.db")

# %%
# Create a question type table
conn.execute('''
CREATE TABLE IF NOT EXISTS question_type (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL
)
'''
)

# Populate it with the following: Binary Search, Graph, Two Pointers, Dynamic Programming
conn.execute('''
INSERT INTO question_type (name) VALUES
    ('Binary Search'),
    ('Graph'),
    ('Two Pointers'),
    ('Dynamic Programming')
'''
)

# Create a question level table
conn.execute('''
CREATE TABLE IF NOT EXISTS question_level (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL
)
'''
)

# Populate it with the following: Easy, Medium, Hard
conn.execute('''
INSERT INTO question_level (name) VALUES
    ('Easy'),
    ('Medium'),
    ('Hard')
'''
)

# Create a questions table
conn.execute('''
CREATE TABLE IF NOT EXISTS questions (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    link TEXT NOT NULL,
    question_type_id INTEGER,
    question_level_id INTEGER,
    FOREIGN KEY (question_type_id) REFERENCES question_type(id),
    FOREIGN KEY (question_level_id) REFERENCES question_level(id)
)
'''
)

conn.commit()

# %% [markdown]
# # Prepare the input to SwellDB
# Since we need to populate the questions table, we need to create all the possible combinations of question types and levels.

# %%
# Get all combinations
combos = """
SELECT 
  qt.id as question_type_id,
  qt.name as question_type_name,
  ql.id as question_level_id,
  ql.name as question_level_name
FROM question_type as qt
CROSS JOIN question_level as ql
"""

# %%
combos = pd.read_sql(combos, conn)
combos
# Out:
#     question_type_id   question_type_name  question_level_id  \
# 0                  1        Binary Search                  1
# 1                  1        Binary Search                  2
# 2                  1        Binary Search                  3
# 3                  2                Graph                  1
# 4                  2                Graph                  2
# 5                  2                Graph                  3
# 6                  3         Two Pointers                  1
# 7                  3         Two Pointers                  2
# 8                  3         Two Pointers                  3
# 9                  4  Dynamic Programming                  1
# 10                 4  Dynamic Programming                  2
# 11                 4  Dynamic Programming                  3
#
#    question_level_name
# 0                 Easy
# 1               Medium
# 2                 Hard
# 3                 Easy
# 4               Medium
# 5                 Hard
# 6                 Easy
# 7               Medium
# 8                 Hard
# 9                 Easy
# 10              Medium
# 11                Hard

# %%
# Convert the combinations to a pyarrow table
data = pa.Table.from_pandas(combos)

# %% [markdown]
# # SwellDB
# Let's populate the *question* table with SwellDB.

# %%
import os
import logging

import datafusion

# SwellDB imports
from swelldb import SwellDB, OpenAILLM
from swelldb.swelldb import Mode
from swelldb.table_plan.table.physical.dataset_table import DatasetTable
from swelldb.table_plan.table.physical.llm_table import LLMTable
from swelldb.table_plan.table.physical.search_engine_table import SearchEngineTable

# Initialize a SwellDB instance
swelldb: SwellDB = SwellDB(
    llm=OpenAILLM(api_key=os.environ["OPENAI_API_KEY"]), 
    serper_api_key=os.environ["SERPER_API_KEY"])

# %%
questions = (
    swelldb.table_builder()
    .set_table_name("question")
    .set_content("A table that contains DSA questions from Leetcode. Given the input data, create as many as possible.")
    .set_schema("name str, link str, question_type_name str, question_type_id int, question_level_name str, question_level_id int")
    .set_base_columns(["question_type_name", "question_level_name"])
    .set_table_gen_mode(Mode.OPERATORS)
    .set_operators([LLMTable, SearchEngineTable])
    .set_data(data)
    .set_chunk_size(20)
).build()

# %%
logging.basicConfig(level=logging.ERROR)

# %%
questions.explain()
# Out:
# SearchEngineTable[schema=['name', 'link', 'question_type_name', 'question_level_name']
# --LLMTable[schema=['question_type_id', 'question_level_id', 'question_level_name', 'question_type_name']

# %%
# Materialize the table
ds = questions.materialize()

sc = datafusion.SessionContext()
sc.deregister_table("questions")
sc.register_dataset("questions", pa.dataset.dataset(ds))

# %%
ds.to_pandas()
# Out:
#                                               name  \
# 0                     Product of Array Except Self
# 1                                    Sort an Array
# 2                 Single Element in a Sorted Array
# 3                                          Two Sum
# 4              Remove Duplicates from Sorted Array
# 5                        Middle of the Linked List
# 6                                Linked List Cycle
# 7                           Palindrome Linked List
# 8                             Odd Even Linked List
# 9                  Maximum Path Quality of a Graph
# 10                        Longest Cycle in a Graph
# 11                            Redundant Connection
# 12                    Find if Path Exists in Graph
# 13                 All Paths From Source to Target
# 14                                     Add Strings
# 15                                   Rotate String
# 16  Longest Substring Without Repeating Characters
# 17                                Multiply Strings
# 18               Binary Tree Level Order Traversal
# 19                     Binary Tree Right Side View
# 20                 Binary Tree Postorder Traversal
# 21                            Balanced Binary Tree
# 22                   Binary Tree Inorder Traversal
# 23                    Find Median from Data Stream
# 24                         Top K Frequent Elements
# 25                                        N-Queens
# 26                                   Binary Search
# 27         All Elements in Two Binary Search Trees
# 28      Convert Sorted Array to Binary Search Tree
# 29                  Search in a Binary Search Tree
# 30                Insert into a Binary Search Tree
# 31                       Container With Most Water
# 32                                       Jump Game
# 33                                Maximum Subarray
# 34                     Median of Two Sorted Arrays
#
#                                                                              link  \
# 0                     https://leetcode.com/problems/product-of-array-except-self/
# 1                                    https://leetcode.com/problems/sort-an-array/
# 2                 https://leetcode.com/problems/single-element-in-a-sorted-array/
# 3                                          https://leetcode.com/problems/two-sum/
# 4              https://leetcode.com/problems/remove-duplicates-from-sorted-array/
# 5                        https://leetcode.com/problems/middle-of-the-linked-list/
# 6                                https://leetcode.com/problems/linked-list-cycle/
# 7                           https://leetcode.com/problems/palindrome-linked-list/
# 8                             https://leetcode.com/problems/odd-even-linked-list/
# 9                  https://leetcode.com/problems/maximum-path-quality-of-a-graph/
# 10                        https://leetcode.com/problems/longest-cycle-in-a-graph/
# 11                            https://leetcode.com/problems/redundant-connection/
# 12                    https://leetcode.com/problems/find-if-path-exists-in-graph/
# 13                 https://leetcode.com/problems/all-paths-from-source-to-target/
# 14                                     https://leetcode.com/problems/add-strings/
# 15                                   https://leetcode.com/problems/rotate-string/
# 16  https://leetcode.com/problems/longest-substring-without-repeating-characters/
# 17                                https://leetcode.com/problems/multiply-strings/
# 18               https://leetcode.com/problems/binary-tree-level-order-traversal/
# 19                     https://leetcode.com/problems/binary-tree-right-side-view/
# 20                 https://leetcode.com/problems/binary-tree-postorder-traversal/
# 21                            https://leetcode.com/problems/balanced-binary-tree/
# 22                   https://leetcode.com/problems/binary-tree-inorder-traversal/
# 23                    https://leetcode.com/problems/find-median-from-data-stream/
# 24                         https://leetcode.com/problems/top-k-frequent-elements/
# 25                                        https://leetcode.com/problems/n-queens/
# 26                                   https://leetcode.com/problems/binary-search/
# 27         https://leetcode.com/problems/all-elements-in-two-binary-search-trees/
# 28      https://leetcode.com/problems/convert-sorted-array-to-binary-search-tree/
# 29                  https://leetcode.com/problems/search-in-a-binary-search-tree/
# 30                https://leetcode.com/problems/insert-into-a-binary-search-tree/
# 31                       https://leetcode.com/problems/container-with-most-water/
# 32                                       https://leetcode.com/problems/jump-game/
# 33                                https://leetcode.com/problems/maximum-subarray/
# 34                     https://leetcode.com/problems/median-of-two-sorted-arrays/
#
#     question_type_name question_level_name  question_type_id  \
# 0                Array                Easy                 1
# 1                Array                Easy                 1
# 2                Array                Easy                 1
# 3                Array                Easy                 1
# 4                Array                Easy                 1
# 5          Linked List              Medium                 2
# 6          Linked List              Medium                 2
# 7          Linked List              Medium                 2
# 8          Linked List              Medium                 2
# 9                Graph                Hard                 3
# 10               Graph                Hard                 3
# 11               Graph                Hard                 3
# 12               Graph                Hard                 3
# 13               Graph                Hard                 3
# 14              String                Easy                 4
# 15              String                Easy                 4
# 16              String                Easy                 4
# 17              String                Easy                 4
# 18                Tree              Medium                 5
# 19                Tree              Medium                 5
# 20                Tree              Medium                 5
# 21                Tree              Medium                 5
# 22                Tree              Medium                 5
# 23                Heap              Medium                 8
# 24                Heap              Medium                 8
# 25        Backtracking                Hard                 9
# 26       Binary Search                Easy                10
# 27       Binary Search                Easy                10
# 28       Binary Search                Easy                10
# 29       Binary Search                Easy                10
# 30       Binary Search                Easy                10
# 31              Greedy              Medium                11
# 32              Greedy              Medium                11
# 33  Divide and Conquer                Hard                12
# 34  Divide and Conquer                Hard                12
#
#     question_level_id
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# 5                   2
# 6                   2
# 7                   2
# 8                   2
# 9                   3
# 10                  3
# 11                  3
# 12                  3
# 13                  3
# 14                  1
# 15                  1
# 16                  1
# 17                  1
# 18                  2
# 19                  2
# 20                  2
# 21                  2
# 22                  2
# 23                  2
# 24                  2
# 25                  3
# 26                  1
# 27                  1
# 28                  1
# 29                  1
# 30                  1
# 31                  2
# 32                  2
# 33                  3
# 34                  3

# %%
sc.sql(""" 
SELECT *
FROM questions
""")
# Out:
# DataFrame()
# +-------------------------------------+--------------------------------------------------------------------+--------------------+---------------------+------------------+-------------------+
# | name                                | link                                                               | question_type_name | question_level_name | question_type_id | question_level_id |
# +-------------------------------------+--------------------------------------------------------------------+--------------------+---------------------+------------------+-------------------+
# | Product of Array Except Self        | https://leetcode.com/problems/product-of-array-except-self/        | Array              | Easy                | 1                | 1                 |
# | Sort an Array                       | https://leetcode.com/problems/sort-an-array/                       | Array              | Easy                | 1                | 1                 |
# | Single Element in a Sorted Array    | https://leetcode.com/problems/single-element-in-a-sorted-array/    | Array              | Easy                | 1                | 1                 |
# | Two Sum                             | https://leetcode.com/problems/two-sum/                             | Array              | Easy                | 1                | 1                 |
# | Remove Duplicates from Sorted Array | https://leetcode.com/problems/remove-duplicates-from-sorted-array/ | Array              | Easy                | 1                | 1                 |
# | Middle of the Linked List           | https://leetcode.com/problems/middle-of-the-linked-list/           | Linked List        | Medium              | 2                | 2                 |
# | Linked List Cycle                   | https://leetcode.com/problems/linked-list-cycle/                   | Linked List        | Medium              | 2                | 2                 |
# | Palindrome Linked List              | https://leetcode.com/problems/palindrome-linked-list/              | Linked List        | Medium              | 2                | 2                 |
# | Odd Even Linked List                | https://leetcode.com/problems/odd-even-linked-list/                | Linked List        | Medium              | 2                | 2                 |
# | Maximum Path Quality of a Graph     | https://leetcode.com/problems/maximum-path-quality-of-a-graph/     | Graph              | Hard                | 3                | 3                 |
# +-------------------------------------+--------------------------------------------------------------------+--------------------+---------------------+------------------+-------------------+
# Data truncated.

# %%
ds.to_pandas().drop(columns=["question_type_name", "question_level_name"]).to_sql("questions", conn, if_exists="append", index=False)
# Out:
# 35

# %%
query = """
SELECT q.name, ql.name as level, q.link
FROM questions q, question_type qt, question_level ql
WHERE q.question_type_id = qt.id
AND q.question_level_id = ql.id
"""

pd.set_option('display.max_colwidth', 400)

df = pd.read_sql(query, conn)

# %%
df
# Out:
#                                               name   level  \
# 0                     Product of Array Except Self    Easy
# 1                                    Sort an Array    Easy
# 2                 Single Element in a Sorted Array    Easy
# 3                                          Two Sum    Easy
# 4              Remove Duplicates from Sorted Array    Easy
# 5                        Middle of the Linked List  Medium
# 6                                Linked List Cycle  Medium
# 7                           Palindrome Linked List  Medium
# 8                             Odd Even Linked List  Medium
# 9                  Maximum Path Quality of a Graph    Hard
# 10                        Longest Cycle in a Graph    Hard
# 11                            Redundant Connection    Hard
# 12                    Find if Path Exists in Graph    Hard
# 13                 All Paths From Source to Target    Hard
# 14                                     Add Strings    Easy
# 15                                   Rotate String    Easy
# 16  Longest Substring Without Repeating Characters    Easy
# 17                                Multiply Strings    Easy
#
#                                                                              link
# 0                     https://leetcode.com/problems/product-of-array-except-self/
# 1                                    https://leetcode.com/problems/sort-an-array/
# 2                 https://leetcode.com/problems/single-element-in-a-sorted-array/
# 3                                          https://leetcode.com/problems/two-sum/
# 4              https://leetcode.com/problems/remove-duplicates-from-sorted-array/
# 5                        https://leetcode.com/problems/middle-of-the-linked-list/
# 6                                https://leetcode.com/problems/linked-list-cycle/
# 7                           https://leetcode.com/problems/palindrome-linked-list/
# 8                             https://leetcode.com/problems/odd-even-linked-list/
# 9                  https://leetcode.com/problems/maximum-path-quality-of-a-graph/
# 10                        https://leetcode.com/problems/longest-cycle-in-a-graph/
# 11                            https://leetcode.com/problems/redundant-connection/
# 12                    https://leetcode.com/problems/find-if-path-exists-in-graph/
# 13                 https://leetcode.com/problems/all-paths-from-source-to-target/
# 14                                     https://leetcode.com/problems/add-strings/
# 15                                   https://leetcode.com/problems/rotate-string/
# 16  https://leetcode.com/problems/longest-substring-without-repeating-characters/
# 17                                https://leetcode.com/problems/multiply-strings/
